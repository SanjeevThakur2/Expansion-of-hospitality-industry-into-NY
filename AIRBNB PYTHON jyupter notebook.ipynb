# %%
# installing geopy module 
pip install geopy

# %%
#importing necessery libraries for future analysis of the dataset
import numpy as np
import statistics as st
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the data set
df_nyc = pd.read_csv('https://raw.githubusercontent.com/som-choudhary/Airbnb/main/Airbnb_new.csv',index_col=0)

# %%
#examing head of csv file 
df_nyc.head(10)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 2   3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
# 12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 13  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
#
#       host_name    borough       neighbourhood  latitude  longitude  \
# 0          John   Brooklyn          kensington  40.64749  -73.97237
# 1      Jennifer  Manhattan             midtown  40.75362  -73.98377
# ...

# %%
# Numeric Analysis

df_nyc.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.263800e+04  4.263800e+04  42607.000000  42609.000000  42602.000000
# mean   1.892386e+07  6.633856e+07     40.725488    -73.949830    148.516173
# std    1.094655e+07  7.755554e+07      0.054140      0.046089    235.828980
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.410163e+06  7.650650e+06     40.688225    -73.979220     65.000000
# 50%    1.956904e+07  3.028359e+07     40.718130    -73.954370    100.000000
# 75%    2.897789e+07  1.056342e+08     40.756690    -73.933800    174.000000
# max    3.648543e+07  2.743115e+08     40.904840    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    42604.000000       42613.000000       33902.000000
# mean         6.974298          23.045080           1.346574
# std         20.295628          44.411525           1.636901
# ...

# %%
# Understanding types
df_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42638 entries, 0 to 48892
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              42638 non-null  int64
#  1   name                            42624 non-null  object
#  2   host_id                         42638 non-null  int64
#  3   host_name                       42582 non-null  object
#  4   borough                         42571 non-null  object
#  5   neighbourhood                   42638 non-null  object
#  6   latitude                        42607 non-null  float64
#  7   longitude                       42609 non-null  float64
#  8   room_type                       42552 non-null  object
#  9   price                           42602 non-null  float64
#  10  minimum_nights                  42604 non-null  float64
#  11  number_of_reviews               42613 non-null  float64
# ...

# %%
# examine null values in all columns in dataframe
df_nyc.isnull().sum()
# Out:
# id                                   0
# name                                14
# host_id                              0
# host_name                           56
# borough                             67
# neighbourhood                        0
# latitude                            31
# longitude                           29
# room_type                           86
# price                               36
# minimum_nights                      34
# number_of_reviews                   25
# last_review                       8746
# reviews_per_month                 8736
# calculated_host_listings_count      16
# availability_365                    42
# dtype: int64

# %%
#checking amount of rows in given dataset to understand the size we are working with
len(df_nyc)
# Out:
# 42638

# %%
# Insight about unique values
df_nyc.nunique()
# Out:
# id                                42638
# name                              41778
# host_id                           32835
# host_name                         10413
# borough                              10
# neighbourhood                       170
# latitude                          17703
# longitude                         14053
# room_type                             3
# price                               634
# minimum_nights                      104
# number_of_reviews                   389
# last_review                        1729
# reviews_per_month                   923
# calculated_host_listings_count       46
# availability_365                    366
# dtype: int64

# %%
# Making sure if any duplicatd values.
df_nyc.duplicated().sum()
# Out:
# 0

# %%
#dropping columns that are not significant or could be unethical to use for our future data exploration and predictions
df_nyc.drop(['host_name','last_review'], axis=1, inplace=True)

#examing the changes
df_nyc.head()
# Out:
#      id                                       name  host_id    borough  \
# 0  2539         Clean & quiet apt home by the park     2787   Brooklyn
# 1  2595                      Skylit Midtown Castle     2845  Manhattan
# 2  3647        THE VILLAGE OF HARLEM....NEW YORK !     4632        NaN
# 3  3831            Cozy Entire Floor of Brownstone     4869   Brooklyn
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322  Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    kensington  40.64749  -73.97237     Private room  149.0             1.0
# 1       midtown  40.75362  -73.98377  Entire home/apt  225.0             1.0
# 2        harlem  40.80902  -73.94190     Private room  150.0             3.0
# 3  clinton hill  40.68514  -73.95976  Entire home/apt   89.0             1.0
# 5   murray hill  40.74767  -73.97500  Entire home/apt  200.0             3.0
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
# examing the column
df_nyc["number_of_reviews"].describe()
# Out:
# count    42613.000000
# mean        23.045080
# std         44.411525
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         23.000000
# max        629.000000
# Name: number_of_reviews, dtype: float64

# %%
# findind the median value
df_nyc["number_of_reviews"].median()
# Out:
# 5.0

# %%
# examing null value
df_nyc.isnull().sum()
# Out:
# id                                   0
# name                                14
# host_id                              0
# borough                             67
# neighbourhood                        0
# latitude                            31
# longitude                           29
# room_type                           86
# price                               36
# minimum_nights                      34
# number_of_reviews                   25
# reviews_per_month                 8736
# calculated_host_listings_count      16
# availability_365                    42
# dtype: int64

# %%
# examing null value
len(df_nyc[(df_nyc["number_of_reviews"]==0.0) & (df_nyc['reviews_per_month'].isna())])
# Out:
# 8718

# %%
# examing null value
df_nyc[df_nyc['reviews_per_month'].isnull()]
# Out:
#              id                                               name    host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres      26394
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 38        11943                          Country space in the city      45445
# 186       46911     Large Room in private Brownstone in Park Slope     210746
# ...         ...                                                ...        ...
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
#
# ...

# %%
# examing null value
df_nyc.isnull().sum()
# Out:
# id                                   0
# name                                14
# host_id                              0
# borough                             67
# neighbourhood                        0
# latitude                            31
# longitude                           29
# room_type                           86
# price                               36
# minimum_nights                      34
# number_of_reviews                   25
# reviews_per_month                 8736
# calculated_host_listings_count      16
# availability_365                    42
# dtype: int64

# %%
# examing the data sheet
df_nyc.shape
# Out:
# (42638, 14)

# %%
# filling the null values in review per month column
a= df_nyc[(df_nyc['number_of_reviews']==0.0) & (df_nyc['reviews_per_month'].isna())]
a
df_nyc.drop(a.index, inplace= True)
df_nyc
a['reviews_per_month'] = 0.00
a
df_nyc =df_nyc.append(a)
df_nyc
# Out:
#              id                                             name    host_id  \
# 0          2539               Clean & quiet apt home by the park       2787
# 1          2595                            Skylit Midtown Castle       2845
# 3          3831                  Cozy Entire Floor of Brownstone       4869
# 5          5099        Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                  BlissArtsSpace!       7356
# ...         ...                                              ...        ...
# 48887  36483152  Garden Jewel Apartment in Williamsburg New York  208514239
# 48889  36484363                               QUIT PRIVATE HOUSE  107716952
# 48890  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057    Affordable room in Bushwick/East Williamsburg    6570630
# 48892  36485431          Sunny Studio at Historical Neighborhood   23492952
#
# ...

# %%
# examing changes
df_nyc[df_nyc["name"] == "THE VILLAGE OF HARLEM....NEW YORK !"]
# Out:
#      id                                 name  host_id borough neighbourhood  \
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632     NaN        harlem
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 2  40.80902   -73.9419  Private room  150.0             3.0
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 2                0.0                0.0                             1.0
#
#    availability_365
# 2             365.0

# %%
# eaxming data sheet
df_nyc.head()
# Out:
#      id                                       name  host_id    borough  \
# 0  2539         Clean & quiet apt home by the park     2787   Brooklyn
# 1  2595                      Skylit Midtown Castle     2845  Manhattan
# 3  3831            Cozy Entire Floor of Brownstone     4869   Brooklyn
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322  Manhattan
# 6  5121                            BlissArtsSpace!     7356   Brooklyn
#
#         neighbourhood  latitude  longitude        room_type  price  \
# 0          kensington  40.64749  -73.97237     Private room  149.0
# 1             midtown  40.75362  -73.98377  Entire home/apt  225.0
# 3        clinton hill  40.68514  -73.95976  Entire home/apt   89.0
# 5         murray hill  40.74767  -73.97500  Entire home/apt  200.0
# 6  bedford-stuyvesant  40.68688  -73.95596              NaN   60.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0             1.0                9.0               0.21
# ...

# %%
# creating dataframe 
d = df_nyc

# %%
# examing median value for review per month
d["reviews_per_month"].median()
# Out:
# 0.36

# %%
# filling null rows
d["reviews_per_month"].fillna(d["reviews_per_month"].median(),inplace = True)

# %%
#examing the changes
d.isnull().sum()
# Out:
# id                                 0
# name                              14
# host_id                            0
# borough                           67
# neighbourhood                      0
# latitude                          31
# longitude                         29
# room_type                         86
# price                             36
# minimum_nights                    34
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count    16
# availability_365                  42
# dtype: int64

# %%
d.sort_index(axis = 0,inplace = True)

# %%
# reseting index in the data sheet
d = d.reset_index()
d
# Out:
#        index        id                                             name  \
# 0          0      2539               Clean & quiet apt home by the park
# 1          1      2595                            Skylit Midtown Castle
# 2          2      3647              THE VILLAGE OF HARLEM....NEW YORK !
# 3          3      3831                  Cozy Entire Floor of Brownstone
# 4          5      5099        Large Cozy 1 BR Apartment In Midtown East
# ...      ...       ...                                              ...
# 42633  48887  36483152  Garden Jewel Apartment in Williamsburg New York
# 42634  48889  36484363                               QUIT PRIVATE HOUSE
# 42635  48890  36484665  Charming one bedroom - newly renovated rowhouse
# 42636  48891  36485057    Affordable room in Bushwick/East Williamsburg
# 42637  48892  36485431          Sunny Studio at Historical Neighborhood
#
#          host_id    borough       neighbourhood  latitude  longitude  \
# ...

# %%
# dropping unnecessary index
d.drop(["index"], axis = 1,inplace = True)

# %%
d.isnull().sum()
# Out:
# id                                 0
# name                              14
# host_id                            0
# borough                           67
# neighbourhood                      0
# latitude                          31
# longitude                         29
# room_type                         86
# price                             36
# minimum_nights                    34
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count    16
# availability_365                  42
# dtype: int64

# %%
# replacing spelling mistakes
d["borough"].replace("Brookly","Brooklyn",inplace = True)

# %%
# replacing spelling mistakes
d['borough'] = d['borough'].replace(['Manhatteen', 'Mahattan',"Manhattn"], 'Manhattan')

# %%
# examimng changes
d[(d["borough"] == "Mahattan") | (d["borough"] == "Manhatteen") | (d["borough"] == "Manhattn")]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, borough, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
# replacing spelling mistakes 
d["borough"].replace("Queen","Queens",inplace = True)

# %%
#Examing changes
d[(d["borough"] == "Queen")]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, borough, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
d.isnull().sum()
# Out:
# id                                 0
# name                              14
# host_id                            0
# borough                           67
# neighbourhood                      0
# latitude                          31
# longitude                         29
# room_type                         86
# price                             36
# minimum_nights                    34
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count    16
# availability_365                  42
# dtype: int64

# %%
d.head()
# Out:
#      id                                       name  host_id    borough  \
# 0  2539         Clean & quiet apt home by the park     2787   Brooklyn
# 1  2595                      Skylit Midtown Castle     2845  Manhattan
# 2  3647        THE VILLAGE OF HARLEM....NEW YORK !     4632        NaN
# 3  3831            Cozy Entire Floor of Brownstone     4869   Brooklyn
# 4  5099  Large Cozy 1 BR Apartment In Midtown East     7322  Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    kensington  40.64749  -73.97237     Private room  149.0             1.0
# 1       midtown  40.75362  -73.98377  Entire home/apt  225.0             1.0
# 2        harlem  40.80902  -73.94190     Private room  150.0             3.0
# 3  clinton hill  40.68514  -73.95976  Entire home/apt   89.0             1.0
# 4   murray hill  40.74767  -73.97500  Entire home/apt  200.0             3.0
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
# examing price vs room type
m = d['price'].groupby(d['room_type'])
m.describe()
# Out:
#                    count        mean         std  min    25%    50%    75%  \
# room_type
# Entire home/apt  21759.0  207.620249  276.767727  0.0  119.0  158.0  225.0
# Private room     19810.0   87.565977  164.351469  0.0   50.0   69.0   90.0
# Shared room        953.0   68.478489  107.851340  0.0   32.0   42.0   70.0
#
#                      max
# room_type
# Entire home/apt  10000.0
# Private room     10000.0
# Shared room       1800.0

# %%
d[d.isna()]
# Out:
#        id name  host_id borough neighbourhood  latitude  longitude room_type  \
# 0     NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# 1     NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# 2     NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# 3     NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# 4     NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# ...    ..  ...      ...     ...           ...       ...        ...       ...
# 42633 NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# 42634 NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# 42635 NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# 42636 NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
# 42637 NaN  NaN      NaN     NaN           NaN       NaN        NaN       NaN
#
# ...

# %%
# creating new dataframe with repect to room type
b = d[d["room_type"].isnull()]

# %%
b
# Out:
#              id                                           name    host_id  \
# 5          5121                                BlissArtsSpace!       7356
# 10         7097              Perfect for Your Parents + Garden      17571
# 16         8490         MAISON DES SIRENES1,bohemian apartment      25183
# 42        14290                     * ORIGINAL BROOKLYN LOFT *      56104
# 48        15385                          Very, very cozy place      60252
# ...         ...                                            ...        ...
# 39680  34722659                     NEW! Chic Designer Vanilla  259468466
# 39683  34723211     Quiet, luxury 1BR--15minutes to Manhattan!   12898160
# 39698  34743695       Spacious 2 br Apartment with Home Office    5993014
# 39701  34745490  Cozy one bedroom apartment with modern touch!  262035496
# 39709  34749431                              Brooklyn Art Cove   60434059
#
#          borough       neighbourhood  latitude  longitude room_type  price  \
# ...

# %%
# dropped null rows in dataframe
d.drop(b.index, inplace= True)
d
# Out:
#              id                                             name    host_id  \
# 0          2539               Clean & quiet apt home by the park       2787
# 1          2595                            Skylit Midtown Castle       2845
# 2          3647              THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                  Cozy Entire Floor of Brownstone       4869
# 4          5099        Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                              ...        ...
# 42633  36483152  Garden Jewel Apartment in Williamsburg New York  208514239
# 42634  36484363                               QUIT PRIVATE HOUSE  107716952
# 42635  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 42636  36485057    Affordable room in Bushwick/East Williamsburg    6570630
# 42637  36485431          Sunny Studio at Historical Neighborhood   23492952
#
# ...

# %%
# created c with respect to price 
c= b[b["price"] >=119.0]
c.head()
# Out:
#         id                                    name  host_id   borough  \
# 10    7097       Perfect for Your Parents + Garden    17571  Brooklyn
# 16    8490  MAISON DES SIRENES1,bohemian apartment    25183  Brooklyn
# 42   14290              * ORIGINAL BROOKLYN LOFT *    56104  Brooklyn
# 213  62925             Beautiful Landmarked Duplex   306739  Brooklyn
# 246  67299  Cozy Garden Apartment  in Williamsburg   330347  Brooklyn
#
#           neighbourhood  latitude  longitude room_type  price  minimum_nights  \
# 10          fort greene  40.69169  -73.97185       NaN  215.0             2.0
# 16   bedford-stuyvesant  40.68371  -73.94028       NaN  120.0             2.0
# 42         williamsburg  40.70420  -73.93560       NaN  228.0             3.0
# 213          greenpoint  40.72945  -73.95511       NaN  285.0             3.0
# 246        williamsburg  40.71492  -73.96282       NaN  135.0            30.0
#
# ...

# %%
# examing room type
c["room_type"] = "Entire home/apt"
c
# Out:
#              id                                               name    host_id  \
# 10         7097                  Perfect for Your Parents + Garden      17571
# 16         8490             MAISON DES SIRENES1,bohemian apartment      25183
# 42        14290                         * ORIGINAL BROOKLYN LOFT *      56104
# 213       62925                        Beautiful Landmarked Duplex     306739
# 246       67299             Cozy Garden Apartment  in Williamsburg     330347
# 260       71248                Bright and lovely 1 bdrm apt in LES     363834
# 6350    5316377   5 Bedroom, 2 Bath, Steps to Train. FREE PARKING!   11137400
# 9226    8052243                     Modern 1BR Apt in Williamsburg   16396888
# 11556   9940337      Top floor of Brooklyn townhouse - South Slope   14314420
# 11560   9943258                     Cozy studio in Upper West Side   20765208
# 12078  10361885                  Dreamy Brownstone Brooklyn Duplex   53330133
# ...

# %%
# created new data frame for price vs room type
m = d['price'].groupby(d['room_type'])
m.describe()
# Out:
#                    count        mean         std  min    25%    50%    75%  \
# room_type
# Entire home/apt  21759.0  207.620249  276.767727  0.0  119.0  158.0  225.0
# Private room     19810.0   87.565977  164.351469  0.0   50.0   69.0   90.0
# Shared room        953.0   68.478489  107.851340  0.0   32.0   42.0   70.0
#
#                      max
# room_type
# Entire home/apt  10000.0
# Private room     10000.0
# Shared room       1800.0

# %%
# created new dataframe for specific range of price
e = b[(b["price"] < 119.0) & (b["price"] >=50.0)]
e.head()
# Out:
#         id                               name  host_id    borough  \
# 5     5121                    BlissArtsSpace!     7356   Brooklyn
# 48   15385              Very, very cozy place    60252        NaN
# 72   20300             Great Location for NYC    76627  Manhattan
# 82   21794        COZY QUIET room 4 DOOGLERS!    83257  Manhattan
# 105  28396  Modern Apt with Spectacular Views  6197784   Brooklyn
#
#           neighbourhood  latitude  longitude room_type  price  minimum_nights  \
# 5    bedford-stuyvesant  40.68688  -73.95596       NaN   60.0            45.0
# 48         williamsburg  40.71185  -73.96204       NaN   80.0             2.0
# 72         east village  40.72912  -73.98057       NaN   50.0             1.0
# 82              chelsea  40.74008  -74.00271       NaN   98.0            30.0
# 105        williamsburg  40.71923  -73.96468       NaN   90.0             1.0
#
#      number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
e["room_type"] = "Private room"
e.head()
# Out:
#         id                               name  host_id    borough  \
# 5     5121                    BlissArtsSpace!     7356   Brooklyn
# 48   15385              Very, very cozy place    60252        NaN
# 72   20300             Great Location for NYC    76627  Manhattan
# 82   21794        COZY QUIET room 4 DOOGLERS!    83257  Manhattan
# 105  28396  Modern Apt with Spectacular Views  6197784   Brooklyn
#
#           neighbourhood  latitude  longitude     room_type  price  \
# 5    bedford-stuyvesant  40.68688  -73.95596  Private room   60.0
# 48         williamsburg  40.71185  -73.96204  Private room   80.0
# 72         east village  40.72912  -73.98057  Private room   50.0
# 82              chelsea  40.74008  -74.00271  Private room   98.0
# 105        williamsburg  40.71923  -73.96468  Private room   90.0
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# 5              45.0               49.0               0.40
# ...

# %%
# created new dataframe for specific range of price
f = b[b["price"] < 50.0]
f.head()
# Out:
#              id                                       name    host_id  \
# 6363    5340170                Spacious room in Park Slope   27240422
# 11585   9959880        great room in sunny cornerapartment   29871124
# 26268  23004287  Brooklyn,  KingsHwy . 1 room for 1 person  166204258
# 26496  23247514           Private room in family apartment   29098546
# 26528  23285672                          Quarto Bronx (NY)  136455880
#
#         borough        neighbourhood  latitude  longitude room_type  price  \
# 6363   Brooklyn           park slope  40.67487  -73.98459       NaN   45.0
# 11585       NaN  morningside heights  40.81508  -73.95935       NaN   49.0
# 26268  Brooklyn       sheepshead bay  40.60920  -73.95720       NaN   27.0
# 26496  Brooklyn   bedford-stuyvesant  40.68082  -73.92162       NaN   29.0
# 26528     Bronx              fordham  40.86918  -73.89050       NaN   34.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
f["room_type"] = "Shared room"
f.head()
# Out:
#              id                                       name    host_id  \
# 6363    5340170                Spacious room in Park Slope   27240422
# 11585   9959880        great room in sunny cornerapartment   29871124
# 26268  23004287  Brooklyn,  KingsHwy . 1 room for 1 person  166204258
# 26496  23247514           Private room in family apartment   29098546
# 26528  23285672                          Quarto Bronx (NY)  136455880
#
#         borough        neighbourhood  latitude  longitude    room_type  price  \
# 6363   Brooklyn           park slope  40.67487  -73.98459  Shared room   45.0
# 11585       NaN  morningside heights  40.81508  -73.95935  Shared room   49.0
# 26268  Brooklyn       sheepshead bay  40.60920  -73.95720  Shared room   27.0
# 26496  Brooklyn   bedford-stuyvesant  40.68082  -73.92162  Shared room   29.0
# 26528     Bronx              fordham  40.86918  -73.89050  Shared room   34.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# appending the changes in the 'd' dataframe 
d =d.append(c)
d
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                                ...        ...
# 32384  29332188  Huge 4 Bedroom 2 Bathroom Townhouse with Backyard     439827
# 32401  29339219  Spacious New 1BR in Sunnyside. Parking available!  114386000
# 33410  30063808               Williamsburg Full-Floor Vintage Loft   16072607
# 33411  30064021                                Modern Harlem Haven  225926055
# 39475  34570816              Sonder | 116 John | Relaxed 1BR + Gym  219517861
#
# ...

# %%
# appending the changes in the 'd' dataframe 
d =d.append(e)
d
# Out:
#              id                                           name    host_id  \
# 0          2539             Clean & quiet apt home by the park       2787
# 1          2595                          Skylit Midtown Castle       2845
# 2          3647            THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                Cozy Entire Floor of Brownstone       4869
# 4          5099      Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                            ...        ...
# 39680  34722659                     NEW! Chic Designer Vanilla  259468466
# 39683  34723211     Quiet, luxury 1BR--15minutes to Manhattan!   12898160
# 39698  34743695       Spacious 2 br Apartment with Home Office    5993014
# 39701  34745490  Cozy one bedroom apartment with modern touch!  262035496
# 39709  34749431                              Brooklyn Art Cove   60434059
#
#          borough    neighbourhood  latitude  longitude        room_type  \
# ...

# %%
# appending the changes in the 'd' dataframe 
d =d.append(f)
d
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                                ...        ...
# 26496  23247514                   Private room in family apartment   29098546
# 26528  23285672                                  Quarto Bronx (NY)  136455880
# 32394  29338253                                Home away from home  221022609
# 39479  34574809  Large Private room - Convenient and safe location  252636577
# 39486  34577268                          The duplex of city center  257474717
#
# ...

# %%
# examing null values 
d.isnull().sum()
# Out:
# id                                 0
# name                              14
# host_id                            0
# borough                           67
# neighbourhood                      0
# latitude                          31
# longitude                         27
# room_type                          0
# price                             30
# minimum_nights                    34
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count    16
# availability_365                  42
# dtype: int64

# %%
# creating new data frame for borough , roomtype vs price
m = d.groupby(['borough',"room_type"])["price"]
m.describe()
# Out:
#                                  count        mean         std   min     25%  \
# borough       room_type
# Bronx         Entire home/apt    232.0  126.857759  103.518748  28.0   79.00
#               Private room       428.0   67.135514  129.210974  10.0   40.00
#               Shared room         31.0   72.806452  137.369676  20.0   29.00
# Brooklyn      Entire home/apt   9127.0  178.783171  226.705721   0.0  105.00
#               Private room      9797.0   76.521997  126.174529   0.0   50.00
#               Shared room        399.0   49.992481   52.946616   0.0   30.00
# Manhattan     Entire home/apt  10348.0  246.646695  329.855440   0.0  140.00
#               Private room      6275.0  114.882709  201.798221  10.0   65.00
#               Shared room        324.0   90.046296  101.668470  10.0   44.00
# Queens        Entire home/apt   1902.0  148.623028  134.094690  10.0   90.00
#               Private room      3137.0   71.434810  186.422714  10.0   47.00
# ...

# %%
# created new dataframe for null price
a = d[d["price"].isnull()]

# %%
a.head()
# Out:
#            id                                            name   host_id  \
# 6        5238              Cute & Cozy Lower East Side 1 bdrm      7549
# 116     32023                                 FLAT MACDONOUGH    137974
# 134     39267                   CENTRAL PARK LOFT all for YOU    168417
# 3805  2909461                     Spacious One Bedroom in UWS  14864202
# 6353  5319150  Modern Williamsburg Apt. Comfort, style, ease!   3865502
#
#         borough       neighbourhood  latitude  longitude        room_type  \
# 6     Manhattan           chinatown  40.71344  -73.99037  Entire home/apt
# 116    Brooklyn  bedford-stuyvesant  40.68296  -73.93662  Entire home/apt
# 134   Manhattan     upper east side  40.77456  -73.95323  Entire home/apt
# 3805  Manhattan     upper west side  40.78352  -73.97482  Entire home/apt
# 6353   Brooklyn        williamsburg  40.71323  -73.95852  Entire home/apt
#
#       price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# examing datasheet
d[d["price"].isnull()]
# Out:
#              id                                               name    host_id  \
# 6          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 116       32023                                    FLAT MACDONOUGH     137974
# 134       39267                      CENTRAL PARK LOFT all for YOU     168417
# 3805    2909461                        Spacious One Bedroom in UWS   14864202
# 6353    5319150     Modern Williamsburg Apt. Comfort, style, ease!    3865502
# 6367    5344850                    Cozy room 15 min from Manhattan   27698133
# 9232    8055508      Private Spring Room in Brownstone Near Subway   40176101
# 11550   9938066                    Madison Avenue Studio Suite (4)   50760546
# 11551   9938208                    Madison Avenue Studio Suite (3)   50760546
# 11562   9943776     Walk to the American Museum of Natural History   37441611
# 12077  10360180                             Seconds to the City!!!   53321966
# ...

# %%
# dropping null values
d.drop(a.index, inplace = True)

# %%
# created new dataframe for borough
b = a[(a["borough"] == "Bronx") & (a["room_type"] == "Entire home/apt")]
b.head()
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, borough, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
# created new dataframe for borough
c = a[(a["borough"] == "Brooklyn") & (a["room_type"] == "Entire home/apt")]
c.head()
# Out:
#              id                                            name   host_id  \
# 116       32023                                 FLAT MACDONOUGH    137974
# 6353    5319150  Modern Williamsburg Apt. Comfort, style, ease!   3865502
# 12077  10360180                          Seconds to the City!!!  53321966
# 12099  10390252          NEW listing! Large Prospect Park 1 Bed   2581816
# 21922  20026598         Bushwick gem with private garden patio.  32446918
#
#         borough       neighbourhood  latitude  longitude        room_type  \
# 116    Brooklyn  bedford-stuyvesant  40.68296  -73.93662  Entire home/apt
# 6353   Brooklyn        williamsburg  40.71323  -73.95852  Entire home/apt
# 12077  Brooklyn            bushwick  40.69177  -73.90451  Entire home/apt
# 12099  Brooklyn            flatbush  40.65003  -73.96000  Entire home/apt
# 21922  Brooklyn            bushwick  40.70451  -73.92062  Entire home/apt
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
c["price"] = 148.0
c.head()
# Out:
#              id                                            name   host_id  \
# 116       32023                                 FLAT MACDONOUGH    137974
# 6353    5319150  Modern Williamsburg Apt. Comfort, style, ease!   3865502
# 12077  10360180                          Seconds to the City!!!  53321966
# 12099  10390252          NEW listing! Large Prospect Park 1 Bed   2581816
# 21922  20026598         Bushwick gem with private garden patio.  32446918
#
#         borough       neighbourhood  latitude  longitude        room_type  \
# 116    Brooklyn  bedford-stuyvesant  40.68296  -73.93662  Entire home/apt
# 6353   Brooklyn        williamsburg  40.71323  -73.95852  Entire home/apt
# 12077  Brooklyn            bushwick  40.69177  -73.90451  Entire home/apt
# 12099  Brooklyn            flatbush  40.65003  -73.96000  Entire home/apt
# 21922  Brooklyn            bushwick  40.70451  -73.92062  Entire home/apt
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# created new dataframe for borough
e = a[(a["borough"] == "Brooklyn") & (a["room_type"] == "Private room")]
e.head()
# Out:
#              id                                               name    host_id  \
# 9232    8055508      Private Spring Room in Brownstone Near Subway   40176101
# 21907  20014534  Minimalist Private Bedroomm - Clean/Spacious/Airy   43010827
# 29711  26786737                                    Harmonious Room  183321912
#
#         borough       neighbourhood  latitude  longitude     room_type  price  \
# 9232   Brooklyn  bedford-stuyvesant  40.68917  -73.92901  Private room    NaN
# 21907  Brooklyn        williamsburg  40.71385  -73.93739  Private room    NaN
# 29711  Brooklyn  bedford-stuyvesant  40.68749  -73.95467  Private room    NaN
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 9232              1.0              291.0               6.23
# 21907             3.0                5.0               0.21
# 29711            30.0               29.0               2.51
#
#        calculated_host_listings_count  availability_365
# ...

# %%
e["price"] = 65.0
e.head()
# Out:
#              id                                               name    host_id  \
# 9232    8055508      Private Spring Room in Brownstone Near Subway   40176101
# 21907  20014534  Minimalist Private Bedroomm - Clean/Spacious/Airy   43010827
# 29711  26786737                                    Harmonious Room  183321912
#
#         borough       neighbourhood  latitude  longitude     room_type  price  \
# 9232   Brooklyn  bedford-stuyvesant  40.68917  -73.92901  Private room   65.0
# 21907  Brooklyn        williamsburg  40.71385  -73.93739  Private room   65.0
# 29711  Brooklyn  bedford-stuyvesant  40.68749  -73.95467  Private room   65.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 9232              1.0              291.0               6.23
# 21907             3.0                5.0               0.21
# 29711            30.0               29.0               2.51
#
#        calculated_host_listings_count  availability_365
# ...

# %%
# created new dataframe for borough
f = a[(a["borough"] == "Brooklyn") & (a["room_type"] == "Shared room")]
f.head()
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, borough, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
# appending values in dataframe
d = d.append(c)

# %%
# appending values in dataframe
d = d.append(e)

# %%
# examing dataframe 
d[(d["borough"] == "Brooklyn") & (d["room_type"] == "Entire home/apt") & (d["price"] == 148.0)]
# Out:
#              id                                               name    host_id  \
# 5812    4786675               Contemporary Luxury Studio Apartment   23852000
# 6112    5013556                 Sunny, modern 1BR in Crown Heights    1387175
# 12849  11574674                Bright 2 bedroom aparment, Bushwick   61175876
# 16429  14869440                        Crown Heights 1 BR w/ Style    7128634
# 18621  16898313      Large 2 bdrm loft with outdoor space + trains    4185119
# 19474  17906420                    Relaxing Brownstone One Bedroom    6899124
# 20883  19221595            Brooklyn Designer 3 Bedrms free parking     131659
# 23319  21151290  BRIGHT AND NEW! 3beds/2baths-Everything you need!   11571496
# 23655  21354957        NEW Large BEAUTIFUL STUDIO -  Williamsburg!  154506785
# 24956  22066430            Chic Williamsburg Mid-Century Apartment   20604809
# 26399  23122597  Brand new two-bedroom apt. in Bensonhurst, Bklyn!   79305630
# ...

# %%
# created new dataframe for borough
c = a[(a["borough"] == "Manhattan") & (a["room_type"] == "Entire home/apt")]
c.head()
# Out:
#             id                                name   host_id    borough  \
# 6         5238  Cute & Cozy Lower East Side 1 bdrm      7549  Manhattan
# 134      39267       CENTRAL PARK LOFT all for YOU    168417  Manhattan
# 3805   2909461         Spacious One Bedroom in UWS  14864202  Manhattan
# 11550  9938066     Madison Avenue Studio Suite (4)  50760546  Manhattan
# 11551  9938208     Madison Avenue Studio Suite (3)  50760546  Manhattan
#
#          neighbourhood  latitude  longitude        room_type  price  \
# 6            chinatown  40.71344  -73.99037  Entire home/apt    NaN
# 134    upper east side  40.77456  -73.95323  Entire home/apt    NaN
# 3805   upper west side  40.78352  -73.97482  Entire home/apt    NaN
# 11550          midtown  40.74892  -73.98280  Entire home/apt    NaN
# 11551          midtown  40.74909  -73.98253  Entire home/apt    NaN
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
c["price"] = 189.0
c.head()
# Out:
#             id                                name   host_id    borough  \
# 6         5238  Cute & Cozy Lower East Side 1 bdrm      7549  Manhattan
# 134      39267       CENTRAL PARK LOFT all for YOU    168417  Manhattan
# 3805   2909461         Spacious One Bedroom in UWS  14864202  Manhattan
# 11550  9938066     Madison Avenue Studio Suite (4)  50760546  Manhattan
# 11551  9938208     Madison Avenue Studio Suite (3)  50760546  Manhattan
#
#          neighbourhood  latitude  longitude        room_type  price  \
# 6            chinatown  40.71344  -73.99037  Entire home/apt  189.0
# 134    upper east side  40.77456  -73.95323  Entire home/apt  189.0
# 3805   upper west side  40.78352  -73.97482  Entire home/apt  189.0
# 11550          midtown  40.74892  -73.98280  Entire home/apt  189.0
# 11551          midtown  40.74909  -73.98253  Entire home/apt  189.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# created new dataframe for borough
e = a[(a["borough"] == "Manhattan") & (a["room_type"] == "Private room")]
e.head()
# Out:
#              id                               name    host_id    borough  \
# 12088  10371643   Nice room in the Upper West Side   53387593  Manhattan
# 26271  23005685                     Luxury Tribeca   51536620  Manhattan
# 33424  30067767          UPPER EAST SIDE in NYC!!!  151300770  Manhattan
# 39489  34582016  New York City!!! Luxury Bedroom!!  224317184  Manhattan
#
#          neighbourhood  latitude  longitude     room_type  price  \
# 12088  upper west side  40.79988  -73.96120  Private room    NaN
# 26271          tribeca       NaN  -74.00984  Private room    NaN
# 33424  upper east side       NaN  -73.95127  Private room    NaN
# 39489           harlem       NaN  -73.94931  Private room    NaN
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 12088            27.0                0.0               0.00
# 26271             NaN                1.0               0.06
# 33424             5.0                5.0               0.79
# ...

# %%
e["price"] = 86.0
e.head()
# Out:
#              id                               name    host_id    borough  \
# 12088  10371643   Nice room in the Upper West Side   53387593  Manhattan
# 26271  23005685                     Luxury Tribeca   51536620  Manhattan
# 33424  30067767          UPPER EAST SIDE in NYC!!!  151300770  Manhattan
# 39489  34582016  New York City!!! Luxury Bedroom!!  224317184  Manhattan
#
#          neighbourhood  latitude  longitude     room_type  price  \
# 12088  upper west side  40.79988  -73.96120  Private room   86.0
# 26271          tribeca       NaN  -74.00984  Private room   86.0
# 33424  upper east side       NaN  -73.95127  Private room   86.0
# 39489           harlem       NaN  -73.94931  Private room   86.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 12088            27.0                0.0               0.00
# 26271             NaN                1.0               0.06
# 33424             5.0                5.0               0.79
# ...

# %%
# appending dataframe with changes 
d = d.append(c)

# %%
# appending dataframe with changes
d = d.append(e)

# %%
# created new dataframe for borough and room type
c = a[(a["borough"] == "Queens") & (a["room_type"] == "Private room")]
c.head()
# Out:
#              id                             name    host_id borough  \
# 6367    5344850  Cozy room 15 min from Manhattan   27698133  Queens
# 33421  30067209                     Just for you  222054756  Queens
#
#       neighbourhood  latitude  longitude     room_type  price  minimum_nights  \
# 6367       woodside  40.74705  -73.89564  Private room    NaN             5.0
# 33421     rego park  40.72637        NaN  Private room    NaN             3.0
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 6367                13.0               0.25                             1.0
# 33421                1.0               0.16                             1.0
#
#        availability_365
# 6367                0.0
# 33421              89.0

# %%
c["price"] = 59.0

# %%
# created new dataframe for borough and room type
e = a[(a["borough"] == "Queens") & (a["room_type"] == "Entire home/apt")]
e.head()
# Out:
#              id                                               name    host_id  \
# 32403  29340021  Home to LGA airport near Manhattan, JFk, Astoria.  221043708
#
#       borough  neighbourhood  latitude  longitude        room_type  price  \
# 32403  Queens  east elmhurst   40.7698  -73.87183  Entire home/apt    NaN
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 32403             1.0               29.0               3.32
#
#        calculated_host_listings_count  availability_365
# 32403                             1.0             360.0

# %%
e["price"] = 120.0

# %%
# appending value to dataframe 
d = d.append(e)

# %%
# appending value to dataframe
d = d.append(c)

# %%
#examimng null value
d.isnull().sum()
# Out:
# id                                 0
# name                              14
# host_id                            0
# borough                           64
# neighbourhood                      0
# latitude                          31
# longitude                         27
# room_type                          0
# price                              0
# minimum_nights                    33
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count    16
# availability_365                  42
# dtype: int64

# %%
# fillning null values
d["name"].fillna("Others", inplace = True)

# %%
# examing null value
d.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# borough                           64
# neighbourhood                      0
# latitude                          31
# longitude                         27
# room_type                          0
# price                              0
# minimum_nights                    33
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count    16
# availability_365                  42
# dtype: int64

# %%
# dropping null values 
d.dropna(subset =["calculated_host_listings_count"], inplace = True)

# %%
# examing null value
d.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# borough                           60
# neighbourhood                      0
# latitude                          31
# longitude                         25
# room_type                          0
# price                              0
# minimum_nights                    28
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                  39
# dtype: int64

# %%
# creating new dataframe for null minimum nights
a = d[d["minimum_nights"].isnull()]
a.head()
# Out:
#         id                                              name  host_id  \
# 9     6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 51   16326        Comfortable 4-bedroom apt in family house.    63588
# 112  30031                  NYC artists’ loft with roof deck   129352
# 151  45556             Fort Greene, Brooklyn: Center Bedroom    67778
# 233  65562                 CHARMING EAST VILLAGE 2 (or 1) BR   320450
#
#        borough     neighbourhood  latitude  longitude        room_type  price  \
# 9    Manhattan   upper west side  40.79826  -73.96113     Private room   85.0
# 51    Brooklyn  prospect heights  40.67811  -73.96428  Entire home/apt  200.0
# 112   Brooklyn        greenpoint  40.73494  -73.95030     Private room   50.0
# 151   Brooklyn       fort greene  40.68863  -73.97691     Private room   65.0
# 233  Manhattan      east village  40.72956  -73.98158  Entire home/apt  129.0
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# dropped null values 
d.drop(a.index, inplace = True)

# %%
# created new dataframe
b = a[a["room_type"] == "Private room"]
b.head()
# Out:
#         id                                              name  host_id  \
# 9     6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 112  30031                  NYC artists’ loft with roof deck   129352
# 151  45556             Fort Greene, Brooklyn: Center Bedroom    67778
# 256  70095            Private Bedroom in Large NYC Apartment   353965
# 276  79782  Williamsburg HUGE, PRIVATE BATH - Next to Train!   430188
#
#        borough    neighbourhood  latitude  longitude     room_type  price  \
# 9    Manhattan  upper west side  40.79826  -73.96113  Private room   85.0
# 112   Brooklyn       greenpoint  40.73494  -73.95030  Private room   50.0
# 151   Brooklyn      fort greene  40.68863  -73.97691  Private room   65.0
# 256  Manhattan           inwood  40.86713  -73.92811  Private room   90.0
# 276   Brooklyn     williamsburg  40.70516  -73.95455  Private room  120.0
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# finding mode(repeated) value 
d[d["room_type"] == "Private room"]["minimum_nights"].value_counts()
# Out:
# 1.0      6886
# 2.0      4715
# 3.0      2835
# 5.0      1068
# 4.0      1029
#          ...
# 44.0        1
# 75.0        1
# 250.0       1
# 47.0        1
# 114.0       1
# Name: minimum_nights, Length: 71, dtype: int64

# %%
d[d["room_type"] == "Private room"]["minimum_nights"].mode()[0]
# Out:
# 1.0

# %%
d[d["room_type"] == "Entire home/apt"]["minimum_nights"].mode()[0]
# Out:
# 2.0

# %%
d[d["room_type"] == "Shared room"]["minimum_nights"].mode()[0]
# Out:
# 1.0

# %%
b["minimum_nights"] = d[d["room_type"] == "Private room"]["minimum_nights"].mode()[0]
b.head()
# Out:
#         id                                              name  host_id  \
# 9     6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 112  30031                  NYC artists’ loft with roof deck   129352
# 151  45556             Fort Greene, Brooklyn: Center Bedroom    67778
# 256  70095            Private Bedroom in Large NYC Apartment   353965
# 276  79782  Williamsburg HUGE, PRIVATE BATH - Next to Train!   430188
#
#        borough    neighbourhood  latitude  longitude     room_type  price  \
# 9    Manhattan  upper west side  40.79826  -73.96113  Private room   85.0
# 112   Brooklyn       greenpoint  40.73494  -73.95030  Private room   50.0
# 151   Brooklyn      fort greene  40.68863  -73.97691  Private room   65.0
# 256  Manhattan           inwood  40.86713  -73.92811  Private room   90.0
# 276   Brooklyn     williamsburg  40.70516  -73.95455  Private room  120.0
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
c = a[a["room_type"] == "Entire home/apt"]
c.head()
# Out:
#              id                                        name   host_id  \
# 51        16326  Comfortable 4-bedroom apt in family house.     63588
# 233       65562           CHARMING EAST VILLAGE 2 (or 1) BR    320450
# 3806    2917698            Crown heights Brooklyn House NYC    263500
# 11543   9936805          Spacious, Bright Studio w/ Balcony   2239025
# 12106  10403199                Mid-Century Museum Sleepover  29065752
#
#          borough     neighbourhood  latitude  longitude        room_type  \
# 51      Brooklyn  prospect heights  40.67811  -73.96428  Entire home/apt
# 233    Manhattan      east village  40.72956  -73.98158  Entire home/apt
# 3806    Brooklyn     east flatbush  40.66411  -73.92905  Entire home/apt
# 11543   Brooklyn       south slope  40.66495  -73.98989  Entire home/apt
# 12106        NaN      williamsburg  40.71863  -73.94528  Entire home/apt
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
c["minimum_nights"] = d[d["room_type"] == "Entire home/apt"]["minimum_nights"].mode()[0]
c.head()
# Out:
#              id                                        name   host_id  \
# 51        16326  Comfortable 4-bedroom apt in family house.     63588
# 233       65562           CHARMING EAST VILLAGE 2 (or 1) BR    320450
# 3806    2917698            Crown heights Brooklyn House NYC    263500
# 11543   9936805          Spacious, Bright Studio w/ Balcony   2239025
# 12106  10403199                Mid-Century Museum Sleepover  29065752
#
#          borough     neighbourhood  latitude  longitude        room_type  \
# 51      Brooklyn  prospect heights  40.67811  -73.96428  Entire home/apt
# 233    Manhattan      east village  40.72956  -73.98158  Entire home/apt
# 3806    Brooklyn     east flatbush  40.66411  -73.92905  Entire home/apt
# 11543   Brooklyn       south slope  40.66495  -73.98989  Entire home/apt
# 12106        NaN      williamsburg  40.71863  -73.94528  Entire home/apt
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
e = a[a["room_type"] == "Shared room"]
e.head()
# Out:
#              id                             name   host_id    borough  \
# 26488  23235654  Only book if your name is Haydn  20725025  Manhattan
#
#          neighbourhood  latitude  longitude    room_type  price  \
# 26488  upper east side  40.77506        NaN  Shared room   80.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 26488             NaN                1.0               0.06
#
#        calculated_host_listings_count  availability_365
# 26488                             1.0             170.0

# %%
e["minimum_nights"] = d[d["room_type"] == "Shared room"]["minimum_nights"].mode()[0]
e.head()
# Out:
#              id                             name   host_id    borough  \
# 26488  23235654  Only book if your name is Haydn  20725025  Manhattan
#
#          neighbourhood  latitude  longitude    room_type  price  \
# 26488  upper east side  40.77506        NaN  Shared room   80.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 26488             1.0                1.0               0.06
#
#        calculated_host_listings_count  availability_365
# 26488                             1.0             170.0

# %%
# appending the value in dataframe
d = d.append(b)

# %%
d = d.append(c)

# %%
d = d.append(e)

# %%
d.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# borough                           60
# neighbourhood                      0
# latitude                          31
# longitude                         25
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                  39
# dtype: int64

# %%
# creating new dataframe for values of availability_365 is null
a = d[d["availability_365"].isnull()]
a.head()
# Out:
#         id                                               name  host_id  \
# 1     2595                              Skylit Midtown Castle     2845
# 37   12940                 Charming Brownstone 3 - Near PRATT    50148
# 66   19169                   Entire 2 Bedroom - Large & Sunny    73128
# 119  32289        Sun-drenched, artsy modernist 1 BDRM duplex   139612
# 161  48719  Designer 1 BR Duplex w/ Terrace- Spectacular V...   221873
#
#        borough       neighbourhood  latitude  longitude        room_type  \
# 1    Manhattan             midtown  40.75362  -73.98377  Entire home/apt
# 37    Brooklyn  bedford-stuyvesant  40.68111  -73.95591  Entire home/apt
# 66   Manhattan     lower east side  40.71851  -73.98892  Entire home/apt
# 119   Brooklyn        williamsburg  40.71561  -73.94835  Entire home/apt
# 161  Manhattan     lower east side  40.71882  -73.98852  Entire home/apt
#
#      price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
#dropped null value
d.drop(a.index, inplace = True)

# %%
# filtered room type
b = a[a["room_type"] =="Private room"]
b.head()
# Out:
#            id                                               name   host_id  \
# 3815  2922197                              Furnished privte room   1447684
# 3819  2925397                 Quaint room in artist's apartment.   8520430
# 6362  5338293  Soho loft, Private bed & bath w/ luxury amenities  14794302
# 6375  5354632          Private Room Inwood Park Top of Manhattan  19931875
# 9229  8053664                       Bare Bones Backyard Bungalow   1112829
#
#         borough neighbourhood  latitude  longitude     room_type  price  \
# 3815   Brooklyn    greenpoint  40.73026  -73.95513  Private room   65.0
# 3819   Brooklyn   south slope  40.66449  -73.99047  Private room   63.0
# 6362  Manhattan          soho  40.72578  -73.99998  Private room  250.0
# 6375  Manhattan        inwood  40.87206  -73.92946  Private room   59.0
# 9229   Brooklyn      bushwick  40.70011  -73.92119  Private room   40.0
#
#       minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# finding mode value for specific room type
d[(d["room_type"] == "Private room")]["availability_365"].mode()[0]
# Out:
# 0.0

# %%
b["availability_365"] = d[(d["room_type"] == "Private room")]["availability_365"].mode()[0]
b.head()
# Out:
#            id                                               name   host_id  \
# 3815  2922197                              Furnished privte room   1447684
# 3819  2925397                 Quaint room in artist's apartment.   8520430
# 6362  5338293  Soho loft, Private bed & bath w/ luxury amenities  14794302
# 6375  5354632          Private Room Inwood Park Top of Manhattan  19931875
# 9229  8053664                       Bare Bones Backyard Bungalow   1112829
#
#         borough neighbourhood  latitude  longitude     room_type  price  \
# 3815   Brooklyn    greenpoint  40.73026  -73.95513  Private room   65.0
# 3819   Brooklyn   south slope  40.66449  -73.99047  Private room   63.0
# 6362  Manhattan          soho  40.72578  -73.99998  Private room  250.0
# 6375  Manhattan        inwood  40.87206  -73.92946  Private room   59.0
# 9229   Brooklyn      bushwick  40.70011  -73.92119  Private room   40.0
#
#       minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
c = a[a["room_type"] =="Entire home/apt"]
c.head()
# Out:
#         id                                               name  host_id  \
# 1     2595                              Skylit Midtown Castle     2845
# 37   12940                 Charming Brownstone 3 - Near PRATT    50148
# 66   19169                   Entire 2 Bedroom - Large & Sunny    73128
# 119  32289        Sun-drenched, artsy modernist 1 BDRM duplex   139612
# 161  48719  Designer 1 BR Duplex w/ Terrace- Spectacular V...   221873
#
#        borough       neighbourhood  latitude  longitude        room_type  \
# 1    Manhattan             midtown  40.75362  -73.98377  Entire home/apt
# 37    Brooklyn  bedford-stuyvesant  40.68111  -73.95591  Entire home/apt
# 66   Manhattan     lower east side  40.71851  -73.98892  Entire home/apt
# 119   Brooklyn        williamsburg  40.71561  -73.94835  Entire home/apt
# 161  Manhattan     lower east side  40.71882  -73.98852  Entire home/apt
#
#      price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
c["availability_365"] = d[(d["room_type"] == "Entire home/apt")]["availability_365"].mode()[0]
c.head()
# Out:
#         id                                               name  host_id  \
# 1     2595                              Skylit Midtown Castle     2845
# 37   12940                 Charming Brownstone 3 - Near PRATT    50148
# 66   19169                   Entire 2 Bedroom - Large & Sunny    73128
# 119  32289        Sun-drenched, artsy modernist 1 BDRM duplex   139612
# 161  48719  Designer 1 BR Duplex w/ Terrace- Spectacular V...   221873
#
#        borough       neighbourhood  latitude  longitude        room_type  \
# 1    Manhattan             midtown  40.75362  -73.98377  Entire home/apt
# 37    Brooklyn  bedford-stuyvesant  40.68111  -73.95591  Entire home/apt
# 66   Manhattan     lower east side  40.71851  -73.98892  Entire home/apt
# 119   Brooklyn        williamsburg  40.71561  -73.94835  Entire home/apt
# 161  Manhattan     lower east side  40.71882  -73.98852  Entire home/apt
#
#      price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
e = a[a["room_type"] =="Shared room"]
e.head()
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, borough, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
e["availability_365"] = d[(d["room_type"] == "Shared room")]["availability_365"].mode()[0]
e.head()
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, borough, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
# appending the changes to dataframe
d = d.append(b)

# %%
d = d.append(c)

# %%
d.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# borough                           60
# neighbourhood                      0
# latitude                          31
# longitude                         25
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                 25
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
# finding mode of number of reviwe column 
d["number_of_reviews"].value_counts()
# Out:
# 0.0      8715
# 1.0      4634
# 2.0      3056
# 3.0      2204
# 4.0      1745
#          ...
# 315.0       1
# 540.0       1
# 441.0       1
# 326.0       1
# 341.0       1
# Name: number_of_reviews, Length: 389, dtype: int64

# %%
# finding mode for specific room type with respect to number of reviews
d[d["room_type"] == "Shared room"]["number_of_reviews"].mode()
# Out:
# 0    0.0
# Name: number_of_reviews, dtype: float64

# %%
d[d["room_type"] == "Entire home/apt"]["number_of_reviews"].mode()
# Out:
# 0    0.0
# Name: number_of_reviews, dtype: float64

# %%
d[d["room_type"] == "Private room"]["number_of_reviews"].mode()
# Out:
# 0    0.0
# Name: number_of_reviews, dtype: float64

# %%
d["number_of_reviews"].dtype
# Out:
# dtype('float64')

# %%
d["number_of_reviews"].fillna(0, inplace = True)

# %%
d.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# borough                           60
# neighbourhood                      0
# latitude                          31
# longitude                         25
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
d[d["number_of_reviews"] == 0].head()
# Out:
#        id                                               name  host_id  \
# 2    3647                THE VILLAGE OF HARLEM....NEW YORK !     4632
# 18   8700  Magnifique Suite au N de Manhattan - vue Cloitres    26394
# 27  11452                        Clean and Quiet in Brooklyn     7355
# 29  11943                          Country space in the city    45445
# 36  12937  1 Stop fr. Manhattan! Private Suite,Landmark B...    50124
#
#       borough       neighbourhood  latitude  longitude     room_type  price  \
# 2         NaN              harlem  40.80902  -73.94190  Private room  150.0
# 18  Manhattan              inwood  40.86754  -73.92639  Private room   80.0
# 27   Brooklyn  bedford-stuyvesant  40.68876  -73.94312  Private room   35.0
# 29   Brooklyn            flatbush  40.63702  -73.96327  Private room  150.0
# 36     Queens    long island city  40.74771  -73.94740  Private room  130.0
#
#     minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# examing null value for borough 
borough_df = d[d["borough"].isnull()]
borough_df.head()
# Out:
#         id                                             name  host_id borough  \
# 2     3647              THE VILLAGE OF HARLEM....NEW YORK !     4632     NaN
# 13    7801                 Sweet and Spacious Brooklyn Loft    21207     NaN
# 30   12048              LowerEastSide apt share shortterm 1     7549     NaN
# 99   27385           Great Large 1 BR apt  in East Village!    72062     NaN
# 127  34760  Sunny Room in Old Historical Brooklyn Townhouse   149929     NaN
#
#        neighbourhood  latitude  longitude        room_type  price  \
# 2             harlem  40.80902  -73.94190     Private room  150.0
# 13      williamsburg  40.71842  -73.95718  Entire home/apt  299.0
# 30   lower east side       NaN  -73.98917      Shared room   40.0
# 99      east village  40.72555  -73.97965  Entire home/apt  225.0
# 127      fort greene  40.69101  -73.97312     Private room   44.0
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# dropping null value in borough column
d.drop(borough_df.index, inplace = True)

# %%
d.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# borough                            0
# neighbourhood                      0
# latitude                          28
# longitude                         22
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
borough_df.shape
# Out:
# (60, 14)

# %%
from geopy.geocoders import Nominatim

#creating object geo for nominatim
geo = Nominatim(user_agent='Getloc')

# finding location with the help of longitude and latitude
loc = geo.reverse("40.80902,-73.9419")
loc.address


loc = geo.reverse("40.71842,-73.95718")
loc.address


loc = geo.reverse("40.71185,-73.96204")
loc.address


loc = geo.reverse("40.72555,-73.97965")
loc.address

loc = geo.reverse("40.69101,-73.97312")
loc.address

loc = geo.reverse("40.69101,-73.97312")
loc.address

loc = geo.reverse("40.73194,-73.99474")
loc.address

loc = geo.reverse("40.80393,-73.95838")
loc.address

loc = geo.reverse("40.68819,-73.97258")
loc.address

loc = geo.reverse("40.68795,-73.97332")
loc.address

loc = geo.reverse("40.68006,-73.97759")
loc.address

loc = geo.reverse("40.75293,-73.97173")
loc.address

loc = geo.reverse("40.71416,-73.9488")
loc.address

loc = geo.reverse("40.67784,-73.94995")
loc.address

loc = geo.reverse("40.694,-73.93472")
loc.address

loc = geo.reverse("40.63304,-74.02811")
loc.address

loc = geo.reverse("40.68927,-73.93035")
loc.address

loc = geo.reverse("40.73178,-73.98842")
loc.address

loc = geo.reverse("40.70511,-73.91755")
loc.address

loc = geo.reverse("40.67902,-73.94747")
loc.address

loc = geo.reverse("40.66557    ,-73.97896")
loc.address

loc = geo.reverse("40.78469    ,-73.9738")
loc.address

loc = geo.reverse("40.78614    ,-73.95541")
loc.address

loc = geo.reverse("40.81508   , -73.95935")
loc.address

loc = geo.reverse("40.74357    ,-73.98466")
loc.address

loc = geo.reverse("40.72508  ,  -73.94488")
loc.address

loc = geo.reverse("40.73144  ,  -73.98355")
loc.address

loc = geo.reverse("40.71863  , -73.94528")
loc.address

loc = geo.reverse("40.77693  , -73.94524")
loc.address

loc = geo.reverse("40.70662   , -74.0051")
loc.address

loc = geo.reverse("40.68868   , -73.99206")
loc.address

loc = geo.reverse("40.80908   , -73.95858")
loc.address

loc = geo.reverse("40.80263  , -73.96458")
loc.address

loc = geo.reverse("40.69444  ,  -73.95257")
loc.address

loc = geo.reverse("40.75207, -73.97201")
loc.address

loc = geo.reverse("40.75946   , -73.96498")
loc.address

loc = geo.reverse("40.70364  ,  -73.93146")
loc.address

loc = geo.reverse("40.67802  ,  -73.9614")
loc.address

loc = geo.reverse("40.70419 ,   -73.75116")
loc.address

loc = geo.reverse("40.74827 , -73.97851")
loc.address

loc = geo.reverse("40.76163  , -73.97113")
loc.address

loc = geo.reverse("40.64745 , -73.94413")
loc.address

loc = geo.reverse("40.6943 ,-73.93935")
loc.address

loc = geo.reverse("40.71335 , -74.00687")
loc.address

loc = geo.reverse("40.74482,   -73.99882")
loc.address

loc = geo.reverse("40.71859 , -73.95284")
loc.address

loc = geo.reverse("40.72541 , -73.98398")
loc.address

loc = geo.reverse("40.69471 , -73.933")
loc.address

loc = geo.reverse("40.68862 ,   -73.95572")
loc.address

loc = geo.reverse("40.70136  , -73.9269")
loc.address

loc = geo.reverse("40.65209 , -74.01136")
loc.address

loc = geo.reverse("40.69196 ,-73.95969")
loc.address

loc = geo.reverse("40.63204 , -73.93383")
loc.address

loc = geo.reverse("40.76529 ,  -73.91137")
loc.address

loc = geo.reverse("40.71235 , -73.95764")
loc.address


loc = geo.reverse("40.82411 , -73.95441")
loc.address

loc = geo.reverse("40.83856 , -73.94186")
loc.address

loc = geo.reverse("40.74305 , -73.99415")
loc.address

loc = geo.reverse("40.78222  ,-73.97676")
loc.address


loc = geo.reverse("40.58495 ,  -73.93278")
loc.address

loc = geo.reverse("40.81304 ,-73.96131")
loc.address

loc = geo.reverse("40.67982 ,-73.94978")
loc.address
# Out:
# 'Stacey Adams Plaza, Herkimer Street, Bedford-Stuyvesant, Brooklyn, Kings County, City of New York, New York, 11207, United States'

# %%
# appending the value of borough as per longitude and latitude 
borough_df.loc[(borough_df['latitude']==40.80902)&(borough_df['longitude']==-73.9419),['borough']]='Manhattan'
borough_df.loc[(borough_df["latitude"]==40.71842)&(borough_df["longitude"]==-73.95718),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==np.NaN)&(borough_df["longitude"]==-73.98917),['borough']]=""
borough_df.loc[(borough_df["latitude"]==40.71185)&(borough_df["longitude"]==-73.96204),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.72555)&(borough_df["longitude"]==-73.97965),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.69101)&(borough_df["longitude"]==-73.97312),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.73194)&(borough_df["longitude"]==-73.99474),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.80393)&(borough_df["longitude"]==-73.95838),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.68819)&(borough_df["longitude"]==-73.97258),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.68795)&(borough_df["longitude"]==-73.97332),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.68006)&(borough_df["longitude"]==-73.97759),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.75293)&(borough_df["longitude"]==-73.97173),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.71416)&(borough_df["longitude"]==-73.9488),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.67784)&(borough_df["longitude"]==-73.94995),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.694)&(borough_df["longitude"]==-73.93472),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.63304)&(borough_df["longitude"]==-74.02811),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.68927)&(borough_df["longitude"]==-73.93035),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.73178)&(borough_df["longitude"]==-73.98842),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.70511)&(borough_df["longitude"]==-73.91755),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.67902)&(borough_df["longitude"]==-73.94747),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.66557)&(borough_df["longitude"]==-73.97896),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.78469)&(borough_df["longitude"]==-73.9738),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.78614)&(borough_df["longitude"]==-73.95541),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.81508)&(borough_df["longitude"]==-73.95935),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.74357)&(borough_df["longitude"]==-73.98466),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.72508)&(borough_df["longitude"]==-73.94488),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.73144)&(borough_df["longitude"]==-73.98355),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.71863)&(borough_df["longitude"]==-73.94528),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.77693)&(borough_df["longitude"]==-73.94524),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.70662)&(borough_df["longitude"]==-74.0051),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.68868)&(borough_df["longitude"]==-73.99206),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.80908)&(borough_df["longitude"]==-73.95858),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.80263)&(borough_df["longitude"]==-73.96458),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.69444)&(borough_df["longitude"]==-73.95257),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.75207)&(borough_df["longitude"]==-73.97201),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.75946)&(borough_df["longitude"]==-73.96498),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.70364)&(borough_df["longitude"]==-73.93146),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.67802)&(borough_df["longitude"]==-73.9614),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.70419)&(borough_df["longitude"]==-73.75116),['borough']]=("Queens")
borough_df.loc[(borough_df["latitude"]==40.74827)&(borough_df["longitude"]==-73.97851),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==np.NaN)&(borough_df["longitude"]==-73.98083),['borough']]=("")
borough_df.loc[(borough_df["latitude"]==40.76163)&(borough_df["longitude"]==-73.97113),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.64745)&(borough_df["longitude"]==-73.94413),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.6943)&(borough_df["longitude"]==-73.93935),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.71335)&(borough_df["longitude"]==-74.00687),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.74482)&(borough_df["longitude"]==-73.99882),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.71859)&(borough_df["longitude"]==-73.95284),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.72541)&(borough_df["longitude"]==-73.98398),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.70918)&(borough_df["longitude"]==np.NaN),['borough']]=("")
borough_df.loc[(borough_df["latitude"]==40.69471)&(borough_df["longitude"]==-73.933),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.67784)&(borough_df["longitude"]==np.NaN),['borough']]=("")
borough_df.loc[(borough_df["latitude"]==40.68862)&(borough_df["longitude"]==-73.95572),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.70136)&(borough_df["longitude"]==-73.9269),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.65209)&(borough_df["longitude"]==-74.01136),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.69196)&(borough_df["longitude"]==-73.95969),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.63204)&(borough_df["longitude"]==-73.93383),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.76529)&(borough_df["longitude"]==-73.91137),['borough']]=("Queens")
borough_df.loc[(borough_df["latitude"]==40.71235)&(borough_df["longitude"]==-73.95764),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.82411)&(borough_df["longitude"]==-73.95441),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.69115)&(borough_df["longitude"]==np.NaN),['borough']]=("")
borough_df.loc[(borough_df["latitude"]==np.NaN)&(borough_df["longitude"]==-73.94781),['borough']]=("")
borough_df.loc[(borough_df["latitude"]==40.83856)&(borough_df["longitude"]==-73.94186),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.74305)&(borough_df["longitude"]==-73.99415),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.78222)&(borough_df["longitude"]==-73.97676),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.58495)&(borough_df["longitude"]==-73.93278),['borough']]=("Brooklyn")
borough_df.loc[(borough_df["latitude"]==40.81304)&(borough_df["longitude"]==-73.96131),['borough']]=("Manhattan")
borough_df.loc[(borough_df["latitude"]==40.67982)&(borough_df["longitude"]==-73.94978),['borough']]=("Brooklyn")

# %%
# examing the changes
borough_df.head()
# Out:
#         id                                             name  host_id  \
# 2     3647              THE VILLAGE OF HARLEM....NEW YORK !     4632
# 13    7801                 Sweet and Spacious Brooklyn Loft    21207
# 30   12048              LowerEastSide apt share shortterm 1     7549
# 99   27385           Great Large 1 BR apt  in East Village!    72062
# 127  34760  Sunny Room in Old Historical Brooklyn Townhouse   149929
#
#        borough    neighbourhood  latitude  longitude        room_type  price  \
# 2    Manhattan           harlem  40.80902  -73.94190     Private room  150.0
# 13    Brooklyn     williamsburg  40.71842  -73.95718  Entire home/apt  299.0
# 30         NaN  lower east side       NaN  -73.98917      Shared room   40.0
# 99   Manhattan     east village  40.72555  -73.97965  Entire home/apt  225.0
# 127  Manhattan      fort greene  40.69101  -73.97312     Private room   44.0
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# examing null values
borough_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# borough                           6
# neighbourhood                     0
# latitude                          3
# longitude                         3
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# rechecking the shape of dataset
borough_df.shape
# Out:
# (60, 14)

# %%
borough_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# borough                           6
# neighbourhood                     0
# latitude                          3
# longitude                         3
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# finding the borough as per neighbour
d[d["neighbourhood"] == "lower east side"].head(1)
# Out:
#         id                                  name  host_id    borough  \
# 113  30927  Unique & Charming small 1br Apt. LES   120335  Manhattan
#
#        neighbourhood  latitude  longitude        room_type  price  \
# 113  lower east side  40.71341  -73.98856  Entire home/apt  105.0
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# 113             3.0               32.0               0.29
#
#      calculated_host_listings_count  availability_365
# 113                             1.0              16.0

# %%
d[d["neighbourhood"] == "east village"].head(1)
# Out:
#       id                              name  host_id    borough neighbourhood  \
# 20  9657  Modern 1 BR / NYC / EAST VILLAGE    21904  Manhattan  east village
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 20   40.7292  -73.98542  Entire home/apt  180.0            14.0
#
#     number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 20               29.0               0.24                             1.0
#
#     availability_365
# 20              67.0

# %%
d[d["neighbourhood"] == "williamsburg"].head(1)
# Out:
#        id                              name  host_id   borough neighbourhood  \
# 45  14377  Williamsburg 1 bedroom Apartment    56512  Brooklyn  williamsburg
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 45  40.70881   -73.9593  Entire home/apt  150.0            30.0
#
#     number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 45              105.0                0.9                             1.0
#
#     availability_365
# 45              30.0

# %%
d[d["neighbourhood"] == "jamaica"].head(1)
# Out:
#         id                   name  host_id borough neighbourhood  latitude  \
# 165  51850  ( F) Excellent/Pvt Rm    27848  Queens       jamaica  40.67252
#
#      longitude     room_type  price  minimum_nights  number_of_reviews  \
# 165  -73.76597  Private room   55.0             2.0               52.0
#
#      reviews_per_month  calculated_host_listings_count  availability_365
# 165               0.49                             2.0             365.0

# %%
d[d["neighbourhood"] == "greenpoint"].head(1)
# Out:
#       id                               name  host_id   borough neighbourhood  \
# 23  9782  Loft in Williamsburg Area w/ Roof    32169  Brooklyn    greenpoint
#
#     latitude  longitude     room_type  price  minimum_nights  \
# 23       NaN  -73.93762  Private room   55.0             4.0
#
#     number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 23              197.0               1.65                             3.0
#
#     availability_365
# 23             284.0

# %%
d[d["neighbourhood"] == "downtown brooklyn"].head(1)
# Out:
#           id                                name  host_id   borough  \
# 1480  765569  Brand New, Boutique Brooklyn Condo  4036700  Brooklyn
#
#           neighbourhood  latitude  longitude        room_type  price  \
# 1480  downtown brooklyn  40.69594  -73.98375  Entire home/apt  175.0
#
#       minimum_nights  number_of_reviews  reviews_per_month  \
# 1480            13.0               64.0                0.8
#
#       calculated_host_listings_count  availability_365
# 1480                             1.0             116.0

# %%
# created newe dataframe for null borough
misingborough = borough_df[borough_df["borough"].isnull()]
misingborough
# Out:
#              id                                               name    host_id  \
# 30        12048                LowerEastSide apt share shortterm 1       7549
# 26272  23006296            East Village penthouse with city views.    1339185
# 29708  26785111                                1 BR, Williamsburg.   44492422
# 29719  26788956  Sun-filled private co-op minutes from JFK and NYC   37678920
# 33434  30081034                                Greenpoint Brooklyn  226035811
# 33430  30071866                 Brooklyn based 1 bedroom apartment   22723123
#
#       borough      neighbourhood  latitude  longitude        room_type  price  \
# 30        NaN    lower east side       NaN  -73.98917      Shared room   40.0
# 26272     NaN       east village       NaN  -73.98083  Entire home/apt  148.0
# 29708     NaN       williamsburg  40.70918        NaN     Private room   73.0
# 29719     NaN            jamaica  40.67784        NaN  Entire home/apt  100.0
# ...

# %%
# replacing the borough's null values with Manhattan 
row2 = misingborough[misingborough["neighbourhood"] == "lower east side"]
row2
row2["borough"].replace(np.NaN,"Manhattan",inplace = True)
row2
# Out:
#        id                                 name  host_id    borough  \
# 30  12048  LowerEastSide apt share shortterm 1     7549  Manhattan
#
#       neighbourhood  latitude  longitude    room_type  price  minimum_nights  \
# 30  lower east side       NaN  -73.98917  Shared room   40.0             1.0
#
#     number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 30              214.0               1.81                             4.0
#
#     availability_365
# 30             188.0

# %%
# replacing the borough's null values with Manhattan 
row3 = misingborough[misingborough["neighbourhood"] == "east village"]
row3
row3["borough"].replace(np.NaN,"Manhattan",inplace = True)
row3
# Out:
#              id                                     name  host_id    borough  \
# 26272  23006296  East Village penthouse with city views.  1339185  Manhattan
#
#       neighbourhood  latitude  longitude        room_type  price  \
# 26272  east village       NaN  -73.98083  Entire home/apt  148.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 26272             4.0               20.0               1.39
#
#        calculated_host_listings_count  availability_365
# 26272                             1.0             121.0

# %%
# replacing the borough's null values with Brooklyn
row4 = misingborough[misingborough["neighbourhood"] == "williamsburg"]
row4
row4["borough"].replace(np.NaN,"Brooklyn",inplace = True)
row4
# Out:
#              id                 name   host_id   borough neighbourhood  \
# 29708  26785111  1 BR, Williamsburg.  44492422  Brooklyn  williamsburg
#
#        latitude  longitude     room_type  price  minimum_nights  \
# 29708  40.70918        NaN  Private room   73.0             5.0
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 29708                1.0               0.12                             1.0
#
#        availability_365
# 29708             249.0

# %%
# replacing the borough's null values with Queens
row5 = misingborough[misingborough["neighbourhood"] == "jamaica"]
row5
row5["borough"].replace(np.NaN,"Queens",inplace = True)
row5
# Out:
#              id                                               name   host_id  \
# 29719  26788956  Sun-filled private co-op minutes from JFK and NYC  37678920
#
#       borough neighbourhood  latitude  longitude        room_type  price  \
# 29719  Queens       jamaica  40.67784        NaN  Entire home/apt  100.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 29719             1.0                7.0                0.6
#
#        calculated_host_listings_count  availability_365
# 29719                             1.0               0.0

# %%
# replacing the borough's null values with Brooklyn
row6 = misingborough[misingborough["neighbourhood"] == "greenpoint"]
row6
row6["borough"].replace(np.NaN,"Brooklyn",inplace = True)
row6
# Out:
#              id                 name    host_id   borough neighbourhood  \
# 33434  30081034  Greenpoint Brooklyn  226035811  Brooklyn    greenpoint
#
#        latitude  longitude     room_type  price  minimum_nights  \
# 33434       NaN  -73.94781  Private room  200.0             7.0
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 33434                0.0                0.0                             1.0
#
#        availability_365
# 33434               0.0

# %%
# replacing the borough's null values with Brooklyn
row7 = misingborough[misingborough["neighbourhood"] == "downtown brooklyn"]
row7
row7["borough"].replace(np.NaN,"Brooklyn",inplace = True)
row7
# Out:
#              id                                name   host_id   borough  \
# 33430  30071866  Brooklyn based 1 bedroom apartment  22723123  Brooklyn
#
#            neighbourhood  latitude  longitude     room_type  price  \
# 33430  downtown brooklyn  40.69115        NaN  Private room   99.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 33430             3.0                1.0               0.41
#
#        calculated_host_listings_count  availability_365
# 33430                             1.0               0.0

# %%
# appending values to d dataframe
d = d.append(borough_df)

# %%
d = d.append(misingborough)

# %%
d = d.append(row2)

# %%
d = d.append(row3)

# %%
d = d.append(row4)

# %%
d = d.append(row5)

# %%
d = d.append(row6)

# %%
d = d.append(row7)

# %%
# examing the dataframe after appending
d.head(10)
# Out:
#       id                                             name  host_id    borough  \
# 0   2539               Clean & quiet apt home by the park     2787   Brooklyn
# 3   3831                  Cozy Entire Floor of Brownstone     4869   Brooklyn
# 4   5099        Large Cozy 1 BR Apartment In Midtown East     7322  Manhattan
# 7   5295                 Beautiful 1br on Upper West Side     7702  Manhattan
# 8   5803   Lovely Room 1, Garden, Best Area, Legal rental     9744   Brooklyn
# 11  7322                                  Chelsea Perfect    18946  Manhattan
# 12  7726  Hip Historic Brownstone Apartment with Backyard    20950   Brooklyn
# 14  8025                         CBG Helps Haiti Room#2.5    22486   Brooklyn
# 15  8110                            CBG Helps Haiti Rm #2    22486   Brooklyn
# 17  8505               Sunny Bedroom Across Prospect Park    25326   Brooklyn
#
#       neighbourhood  latitude  longitude        room_type  price  \
# ...

# %%
# checking null values
d.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# borough                           12
# neighbourhood                      0
# latitude                          37
# longitude                         31
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
# Examing the brough and room type with respect to price 
m = d.groupby(["borough","room_type"])["price"]
m.describe()
# Out:
#                                  count        mean         std   min     25%  \
# borough       room_type
# Bronx         Entire home/apt    232.0  126.857759  103.518748  28.0   79.00
#               Private room       428.0   67.135514  129.210974  10.0   40.00
#               Shared room         31.0   72.806452  137.369676  20.0   29.00
# Brooklyn      Entire home/apt   9142.0  178.746883  226.536113   0.0  105.00
#               Private room      9818.0   76.514667  126.036158   0.0   50.00
#               Shared room        400.0   49.980000   52.880815   0.0   30.00
# Manhattan     Entire home/apt  10366.0  246.623191  329.607731   0.0  140.00
#               Private room      6290.0  114.896661  201.659914  10.0   65.00
#               Shared room        326.0   89.766871  101.418346  10.0   44.00
# Queens        Entire home/apt   1902.0  148.518402  134.054220  10.0   90.00
#               Private room      3140.0   71.412102  186.335715  10.0   47.00
# ...

# %% [markdown]
# Q1=df.quantile(0.25)
# Q3=df.quantile(0.75)
# IQR=Q3-Q1
# df_drop=df[((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR)))]

# %%
# finding outliers in price column
a = d[(d["borough"] == "Brooklyn") & (d["room_type"] == "Entire home/apt")]
a.head()
# Out:
#        id                                             name  host_id   borough  \
# 3    3831                  Cozy Entire Floor of Brownstone     4869  Brooklyn
# 12   7726  Hip Historic Brownstone Apartment with Backyard    20950  Brooklyn
# 28  11708                        Cute apt in artist's home    44145  Brooklyn
# 32  12299              Beautiful Sunny Park Slope Brooklyn    47610  Brooklyn
# 38  13050                        bright and stylish duplex    50846  Brooklyn
#
#          neighbourhood  latitude  longitude        room_type  price  \
# 3         clinton hill  40.68514  -73.95976  Entire home/apt   89.0
# 12       crown heights  40.67592  -73.94694  Entire home/apt   99.0
# 28            bushwick  40.70186  -73.92745  Entire home/apt   85.0
# 32         south slope  40.66278  -73.97966  Entire home/apt  120.0
# 38  bedford-stuyvesant  40.68554  -73.94090  Entire home/apt  115.0
#
#     minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# dropping  rows 
d.drop(a.index, inplace = True)

# %%
# calculating outliers
Q1=a["price"].quantile(0.25)
Q3=a["price"].quantile(0.75)
IQR=Q3-Q1

# %%
IQR
# Out:
# 94.0

# %%
# finding upper wisker and lower wisker
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)

# %%
up_w
# Out:
# 340.0

# %%
L_w
# Out:
# -36.0

# %%
#replacing the outlier with upper wisker and lower wisker
a["price"] = a["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
#examing the price data set
a["price"].describe()
# Out:
# count    9142.000000
# mean      161.423977
# std        73.622711
# min         0.000000
# 25%       105.000000
# 50%       148.000000
# 75%       199.000000
# max       340.000000
# Name: price, dtype: float64

# %%
# finding outliers for specific borough and room type
b = d[(d["borough"] == "Brooklyn") & (d["room_type"] == "Private room")]

# %%
d.drop(b.index, inplace = True)

# %%
Q1=b["price"].quantile(0.25)
Q3=b["price"].quantile(0.75)
IQR=Q3-Q1

# %%
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)

# %%
b["price"] = b["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
c = d[(d["borough"] == "Brooklyn") & (d["room_type"] == "Shared room")]
d.drop(c.index, inplace = True)
Q1=c["price"].quantile(0.25)
Q3=c["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
c["price"] = c["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
# appending outliers to the main dataframe
d = d.append(a)
d = d.append(b)
d = d.append(c)

# %%
a = d[(d["borough"] == "Bronx") & (d["room_type"] == "Entire home/apt")]
d.drop(a.index, inplace = True)
Q1=a["price"].quantile(0.25)
Q3=a["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
a["price"] = a["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
b = d[(d["borough"] == "Bronx") & (d["room_type"] == "Private room")]
d.drop(b.index, inplace = True)
Q1=b["price"].quantile(0.25)
Q3=b["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
b["price"] = b["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
c = d[(d["borough"] == "Bronx") & (d["room_type"] == "Shared room")]
d.drop(c.index, inplace = True)
Q1=c["price"].quantile(0.25)
Q3=c["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
c["price"] = c["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
d = d.append(a)
d = d.append(b)
d = d.append(c)

# %%
a = d[(d["borough"] == "Manhattan") & (d["room_type"] == "Entire home/apt")]
d.drop(a.index, inplace = True)
Q1=a["price"].quantile(0.25)
Q3=a["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
a["price"] = a["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
b = d[(d["borough"] == "Manhattan") & (d["room_type"] == "Private room")]
d.drop(b.index, inplace = True)
Q1=b["price"].quantile(0.25)
Q3=b["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
b["price"] = b["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
c = d[(d["borough"] == "Manhattan") & (d["room_type"] == "Shared room")]
d.drop(c.index, inplace = True)
Q1=c["price"].quantile(0.25)
Q3=c["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
c["price"] = c["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
d = d.append(a)
d = d.append(b)
d = d.append(c)

# %%
a = d[(d["borough"] == "Manhattan") & (d["room_type"] == "Entire home/apt")]
d.drop(a.index, inplace = True)
Q1=a["price"].quantile(0.25)
Q3=a["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
a["price"] = a["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
b = d[(d["borough"] == "Manhattan") & (d["room_type"] == "Private room")]
d.drop(b.index, inplace = True)
Q1=b["price"].quantile(0.25)
Q3=b["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
b["price"] = b["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
c = d[(d["borough"] == "Manhattan") & (d["room_type"] == "Shared room")]
d.drop(c.index, inplace = True)
Q1=c["price"].quantile(0.25)
Q3=c["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
c["price"] = c["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
d = d.append(a)
d = d.append(b)
d = d.append(c)

# %%
a = d[(d["borough"] == "Queens") & (d["room_type"] == "Entire home/apt")]
d.drop(a.index, inplace = True)
Q1=a["price"].quantile(0.25)
Q3=a["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
a["price"] = a["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
b = d[(d["borough"] == "Queens") & (d["room_type"] == "Private room")]
d.drop(b.index, inplace = True)
Q1=b["price"].quantile(0.25)
Q3=b["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
b["price"] = b["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
c = d[(d["borough"] == "Queens") & (d["room_type"] == "Shared room")]
d.drop(c.index, inplace = True)
Q1=c["price"].quantile(0.25)
Q3=c["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
c["price"] = c["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
d = d.append(a)
d = d.append(b)
d = d.append(c)

# %%
a = d[(d["borough"] == "Staten Island") & (d["room_type"] == "Entire home/apt")]
d.drop(a.index, inplace = True)
Q1=a["price"].quantile(0.25)
Q3=a["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
a["price"] = a["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
b = d[(d["borough"] == "Staten Island") & (d["room_type"] == "Private room")]
d.drop(b.index, inplace = True)
Q1=b["price"].quantile(0.25)
Q3=b["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
b["price"] = b["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
c = d[(d["borough"] == "Staten Island") & (d["room_type"] == "Shared room")]
d.drop(c.index, inplace = True)
Q1=c["price"].quantile(0.25)
Q3=c["price"].quantile(0.75)
IQR=Q3-Q1
up_w = Q3 +(1.5*IQR)
L_w = Q1 - (1.5 * IQR)
c["price"] = c["price"].apply(lambda x: up_w if x > up_w else (L_w if x<L_w else x))

# %%
d = d.append(a)
d = d.append(b)
d = d.append(c)

# %%
m = d.groupby(["borough","room_type"])["price"]
m.describe()
# Out:
#                                  count        mean        std     min     25%  \
# borough       room_type
# Bronx         Entire home/apt    232.0  111.980603  47.997437  28.000   79.00
#               Private room       428.0   56.746495  21.140062  10.000   40.00
#               Shared room         31.0   49.201613  24.539035  20.000   29.00
# Brooklyn      Entire home/apt   9142.0  161.423977  73.622711   0.000  105.00
#               Private room      9818.0   68.308108  25.161580   5.000   50.00
#               Shared room        400.0   41.480938  17.673134   1.125   30.00
# Manhattan     Entire home/apt  10366.0  210.025468  95.692076   0.000  140.00
#               Private room      6290.0   95.810334  42.093674  10.000   65.00
#               Shared room        326.0   74.463190  39.001896  10.000   44.00
# Queens        Entire home/apt   1902.0  137.362776  64.116238  10.000   90.00
#               Private room      3140.0   63.457962  23.011857  10.000   47.00
# ...

# %%
d = d.reset_index()

# %%
d.head(3)
# Out:
#    index     id                                             name  host_id  \
# 0      3   3831                  Cozy Entire Floor of Brownstone     4869
# 1     12   7726  Hip Historic Brownstone Apartment with Backyard    20950
# 2     28  11708                        Cute apt in artist's home    44145
#
#     borough  neighbourhood  latitude  longitude        room_type  price  \
# 0  Brooklyn   clinton hill  40.68514  -73.95976  Entire home/apt   89.0
# 1  Brooklyn  crown heights  40.67592  -73.94694  Entire home/apt   99.0
# 2  Brooklyn       bushwick  40.70186  -73.92745  Entire home/apt   85.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0             1.0              270.0               4.64
# 1             3.0               53.0               4.44
# 2             2.0              231.0               1.96
#
#    calculated_host_listings_count  availability_365
# 0                             1.0             194.0
# ...

# %%
d.drop(["index"], axis = 1, inplace =True)
d.head()
# Out:
#       id                                             name  host_id   borough  \
# 0   3831                  Cozy Entire Floor of Brownstone     4869  Brooklyn
# 1   7726  Hip Historic Brownstone Apartment with Backyard    20950  Brooklyn
# 2  11708                        Cute apt in artist's home    44145  Brooklyn
# 3  12299              Beautiful Sunny Park Slope Brooklyn    47610  Brooklyn
# 4  13050                        bright and stylish duplex    50846  Brooklyn
#
#         neighbourhood  latitude  longitude        room_type  price  \
# 0        clinton hill  40.68514  -73.95976  Entire home/apt   89.0
# 1       crown heights  40.67592  -73.94694  Entire home/apt   99.0
# 2            bushwick  40.70186  -73.92745  Entire home/apt   85.0
# 3         south slope  40.66278  -73.97966  Entire home/apt  120.0
# 4  bedford-stuyvesant  40.68554  -73.94090  Entire home/apt  115.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# exporting dataframe to csv file in local system
d.to_csv(r"C:\Users\hp\OneDrive\Desktop\airbnb.csv")
